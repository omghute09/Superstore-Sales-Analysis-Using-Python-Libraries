# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tr=pd.read_csv(r"C:\Users\ASUS\Downloads\Sample - Superstore.csv",encoding='latin-1')

# %%
tr.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
tr.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
tr.shape
# Out:
# (9994, 21)

# %%
tr.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
tr.duplicated().sum()
# Out:
# np.int64(0)

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ***Converting date columns in datetiime***

# %%
tr['Order Date']=pd.to_datetime(tr['Order Date'])
tr['Ship Date']=pd.to_datetime(tr['Ship Date'])

# %%
tr['Month']=tr['Order Date'].dt.month
tr['Year']=tr['Order Date'].dt.year
tr['order day of Week']=tr['Order Date'].dt.dayofweek

# %%
tr.groupby('Order ID')['Sales'].sum().mean()
# Out:
# np.float64(458.61466566180883)

# %%
tr['Sales'].sum()
# Out:
# np.float64(2297200.8603000003)

# %%
tr['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
tr.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
tr.groupby('Year')['Sales'].sum()
# Out:
# Year
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %%
tr.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# ***Monthly sales analysis***

# %%
tr.groupby('Month')['Sales'].sum().plot(kind='line',xlabel="Months",ylabel="Sales",title="Monthly sales analysis")
# Out:
# <Axes: title={'center': 'Monthly sales analysis'}, xlabel='Months', ylabel='Sales'>

# %%
gp=tr.groupby('Month')['Sales'].sum()

# %%
plt.plot(gp,color='red')
plt.figure(figsize=(10,8))

# %%
tr.groupby('Order ID')['Sales'].sum().mean()
# Out:
# np.float64(458.61466566180883)

# %% [markdown]
# ***Sales By Category***

# %%
tr.groupby('Category')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
tr.groupby('Category')['Sales'].sum().sort_values(ascending=False).head(1)
#f.sort_values(by="column_name", ascending=False)
# Out:
# Category
# Technology    836154.033
# Name: Sales, dtype: float64

# %%
y=tr.groupby('Category')['Sales'].sum()

# %%
plt.pie(y.values,labels=y.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c77acee900>,
# ...
#  [Text(0.5806250883943506, 0.9342775319609546, 'Furniture'),
#   Text(-1.0908936259884885, 0.14124835141582345, 'Office Supplies'),
#   Text(0.45584989144183646, -1.0010998334194579, 'Technology')],
#  [Text(0.31670459366964576, 0.509605926524157, '32.3%'),
#   Text(-0.5950328869028119, 0.07704455531772188, '31.3%'),
#   Text(0.24864539533191077, -0.5460544545924314, '36.4%')])

# %% [markdown]
# ***Sales By Sub-Category***

# %%
tr.isnull().sum()
# Out:
# Row ID               0
# Order ID             0
# Order Date           0
# Ship Date            0
# Ship Mode            0
# Customer ID          0
# Customer Name        0
# Segment              0
# Country              0
# City                 0
# State                0
# Postal Code          0
# Region               0
# Product ID           0
# Category             0
# Sub-Category         0
# Product Name         0
# Sales                0
# Quantity             0
# Discount             0
# Profit               0
# Month                0
# Year                 0
# order day of Week    0
# dtype: int64

# %%
tr.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
tr.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
tr.nlargest(2, 'Sales')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
# 6826    TC-20980  Tamara Chand    Corporate  United States     Lafayette  ...
#
#         Category  Sub-Category  \
# 2697  Technology      Machines
# 6826  Technology       Copiers
#
#                                            Product Name     Sales Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48        6
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.95        5
#
#      Discount     Profit  Month  Year  order day of Week
# 2697      0.5 -1811.0784      3  2014                  1
# 6826      0.0  8399.9760     10  2016                  6
#
# [2 rows x 24 columns]

# %%
r=tr.groupby('Sub-Category')['Sales']

# %%
tr.groupby('Sub-Category')['Sales'].sum().plot(kind='bar',figsize=(10,8))
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
tr.nlargest(1,'Profit')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
#
#      Customer ID Customer Name    Segment        Country       City  ...  \
# 6826    TC-20980  Tamara Chand  Corporate  United States  Lafayette  ...
#
#         Category  Sub-Category                           Product Name  \
# 6826  Technology       Copiers  Canon imageCLASS 2200 Advanced Copier
#
#          Sales Quantity Discount    Profit  Month  Year  order day of Week
# 6826  17499.95        5      0.0  8399.976     10  2016                  6
#
# [1 rows x 24 columns]

# %%
tr.groupby('Month')['Profit'].sum()
# Out:
# Month
# 1      9134.4461
# 2     10294.6107
# 3     28594.6872
# 4     11587.4363
# 5     22411.3078
# 6     21285.7954
# 7     13832.6648
# 8     21776.9384
# 9     36857.4753
# 10    31784.0413
# 11    35468.4265
# 12    43369.1919
# Name: Profit, dtype: float64

# %%
tr.groupby('Month')['Profit'].sum().plot(kind='line',color='red',xlabel='Months',ylabel='Profit',title='Monthly Profit',figsize=(10,9))
# Out:
# <Axes: title={'center': 'Monthly Profit'}, xlabel='Months', ylabel='Profit'>

# %%
tr.groupby('Sub-Category')['Profit'].sum()
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
prf=tr.groupby('Category')['Profit'].sum()
plt.pie(prf.values,labels=prf.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c77be67c50>,
# ...
#  [Text(1.0775459311518438, 0.221121609658816, 'Furniture'),
#   Text(-0.1943855467885104, 1.082688440503422, 'Office Supplies'),
#   Text(-0.02722403643788457, -1.0996630628697268, 'Technology')],
#  [Text(0.5877523260828239, 0.1206117870866269, '6.4%'),
#   Text(-0.10602848006646019, 0.5905573311836847, '42.8%'),
#   Text(-0.014849474420664307, -0.5998162161107601, '50.8%')])

# %%
tr.groupby('Category')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
tr.groupby('Category')['Profit'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
tr.groupby('Sub-Category')['Profit'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
tr.groupby('Segment')['Profit'].sum()
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
tr.groupby('Category').aggregate({'Sales':'sum','Profit':'sum'}).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
tr.groupby('Segment').aggregate({'Sales':'sum','Profit':'sum'}).plot(kind='bar')
# Out:
# <Axes: xlabel='Segment'>

# %%
ty=tr.groupby('Segment').aggregate({'Sales':'sum','Profit':'sum'})
ty['Ratio']=ty['Sales'] / ty['Profit']
print(ty['Ratio'])
# Out:
# Segment
# Consumer       8.659471
# Corporate      7.677245
# Home Office    7.125416
# Name: Ratio, dtype: float64
